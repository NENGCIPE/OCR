# %%
import json
file = json.load(open('handwriting_data_info_clean.json'))
file.keys()#dict_keys(['Annotation', 'Dataset', 'Images', 'bbox'])
file['info']#{'name': '한글 손글씨 데이터', 'date_created': '2019-09-18 04:45:22'}
type(file['images'])#list
#{"id": "00000002", "width": 3755, "height": 176, "file_name": "00000002.png", "license": "AI 오픈 이노베이션 허브"},
# Out:
# list

# %%
file['images'][:3]
# Out:
# [{'id': '00000002',
#   'width': 3755,
#   'height': 176,
#   'file_name': '00000002.png',
#   'license': 'AI 오픈 이노베이션 허브'},
#  {'id': '00000003',
#   'width': 3739,
#   'height': 175,
#   'file_name': '00000003.png',
#   'license': 'AI 오픈 이노베이션 허브'},
#  {'id': '00000004',
#   'width': 3716,
#   'height': 177,
#   'file_name': '00000004.png',
#   'license': 'AI 오픈 이노베이션 허브'}]

# %%
file['images'][0]['license']
# Out:
# 'AI 오픈 이노베이션 허브'

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread('./img_file/1_sentence/00000019.png')
plt.imshow(img)
